# %% [markdown]
# <a href="https://colab.research.google.com/github/fmuranda/Python-for-Data-Science-and-Machine-Learning-Essential-Training-Part-1/blob/main/Multivariate_analysis_for_outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sns.set_style('whitegrid')

# %%
address = 'iris.data.csv'
df = pd.read_csv(filepath_or_buffer=address, header=None, sep=',')

df.columns = ['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid', 'class']
x =df.iloc[:,0:4].values
y = df.iloc[:,4].values
df[:5]
# Out:
#    sepal_len  sepal_wid  petal_len  petal_wid   class
# 0        5.1        3.5        1.4        0.2  setosa
# 1        4.9        3.0        1.4        0.2  setosa
# 2        4.7        3.2        1.3        0.2  setosa
# 3        4.6        3.1        1.5        0.2  setosa
# 4        5.0        3.6        1.4        0.2  setosa

# %%
sns.boxplot(x='class', y='sepal_len', data = df, hue = 'class', palette = 'hls', legend = False)
# Out:
# <Axes: xlabel='class', ylabel='sepal_len'>

# %%
sns.pairplot(df, hue = 'class', palette = 'hls')
