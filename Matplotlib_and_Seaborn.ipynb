# %% [markdown]
# <a href="https://colab.research.google.com/github/fmuranda/Python-for-Data-Science-and-Machine-Learning-Essential-Training-Part-1/blob/main/Matplotlib_and_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import DataFrame
import pandas as pd

# %% [markdown]
# Data

# %%
data = {'names':[' steve ', ' john', 'richard', 'sarah', 'randy', 'micheal', 'julie'],
        'age':[20, 22, 20, 21, 24, 23, 22],
        'gender':[ 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female'],
        'rank':[2,1,4,5,3,7,6]}

df = DataFrame(data)
df
# Out:
#      names  age  gender  rank
# 0   steve    20    Male     2
# 1     john   22    Male     1
# 2  richard   20    Male     4
# 3    sarah   21  Female     5
# 4    randy   24    Male     3
# 5  micheal   23    Male     7
# 6    julie   22  Female     6

# %% [markdown]
# Plot Bargraph - Matplotlib

# %%
plt.bar(df['names'], df['age'])
plt.xlabel('Names')
plt.ylabel('Age')
plt.title('Comparing Ages')
plt.show()

# %% [markdown]
# Plot bargraph - seaborn

# %%
plot = sns.barplot(x='names', y='age', data=df)
plot.set_title('Comparing Ages')
plt.show()

# %% [markdown]
# Plot Linegraph - Matplotlib

# %%
plt.plot(df['names'], df['age'])
plt.xlabel('Names')
plt.ylabel('Age')
plt.title('Comparing Ages')
plt.show()

# %% [markdown]
# Plot Linegraph - Seaborn

# %%
plot = sns.lineplot(x='names', y='age', data=df)
plot.set_title('Comparing Ages')
plt.show()

# %% [markdown]
# Plot Piechart

# %%
plt.pie(df['age'], labels=df['names'])
plt.title('Comparing Ages')
plt.show()
#

# %% [markdown]
# Use Seaborn Color Palette (*Seaborn has less code but makes beautiful plots*)

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie(df['age'], labels=df['names'], colors=colors)
plt.title('Comparing Ages')
plt.show()

# %%
import pandas as pd
address = 'mtcars.csv'
cars = pd.read_csv(address)
cars.columns = ['car_names', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs','am','gear','carb']
mpg = cars['mpg']

# %%
mpg.plot()
# Out:
# <Axes: >

# %%
df = cars[['cyl','wt','mpg']]
df.plot()
# Out:
# <Axes: >

# %%
x = cars['car_names']
y = cars['mpg']
plt.bar(x,y)
plt.xlabel('Car Names')
plt.ylabel('Miles Per Gallon')
plt.title('Car MPG Comparison')
plt.xticks(rotation=90)
plt.show()

# %%
mpg.plot(kind='bar')
# Out:
# <Axes: >

# %%
mpg.plot(kind='barh')
# Out:
# <Axes: >

# %%
x = [1,2,3,4,0.5]
plt.pie(x)
plt.savefig('pie_chart.png')
plt.show()
